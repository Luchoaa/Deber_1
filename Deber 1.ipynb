# %% [markdown]
# Deber #1
# Luis Astudillo
# 00211000

# %%
#Ejercicio 1
#Sort the following functions in decreasing order of asymptotic complexity ($O(f(n))$):

f2() <= f1() <= f4() <= f3()

# %%
#Ejercicio 3 (2.1.4)
aux = 0

for i < n{
    C[i+n] = (A[i]+b[i] + aux)
    if(C[i] >=2){
        aux = 1
    }else{aux = 0}
}
# Out:
#   File "<ipython-input-13-a5a8fe396637>", line 4
#     for i < n{
#           ^
# SyntaxError: invalid syntax

# %%
#Ejercicio 4 (3.1.1)

Con la definicion de teta

 0 <= c1*G(n) <= F(n) <= c2*G(n)
 0 <= c1(f(n) + g(n)) <= max(f(n), g(n)) <= c2(f(n) + g(n))

La condicion de  0 <= c1(f(n) + g(n)) siempre se cumple

Si c1 = 1/2 -> Se cumple la condicion de que 
c1(f(n) + g(n)) = max(f(n), g(n))

Si c2 = 1 -> Se cumple la condicion de que 
 max(f(n), g(n)) <= c2(f(n) + g(n))

Ya que todas las condiciones se cumplen, se da por hecho que 
 max(f(n), g(n))= θ(f(n) + g(n))

# %%
#Ejercicio 5 (3.1-2)

(n+a)^b = θ(n^b)
Si
(n+a)<= 2n --> a >= n 
Si 
(n+a)>=n/2
a <= n/2
Por lo tanto tenemos que 
n/2 <= n+a <= 2n

Si las elevamos a la potencia b obtenemos los valores de 
c1 = (1/2)^b
c2 = (2^b)

Por lo tanto (n+a)^b = θ(n^b)

# %%
#Ejercicio 6 (3.1-6)

En base al teorema 3.1 

Tm el mejor tiempo y Tp el peor tiempo sabemos que 

C1*g(n)<= Tm(n)
Tp(n) <= C2*g(n)

por lo que 

C1*g(n)<= Tm(n) <= Tp(n) <= C2*g(n)

Como el tiempo va a estar entre Tp y Tm provamos la notacion de θ

# %%
#Ejercicio 7 (3.-4 a,b,e,g)

a)Falso
Ya que n = O(n^2) pero n^2 != O(n)


b)Falso
Ya que n+n^2 != θ(n)


e)Falso


g)Falso
f(n) = 2^2n pero 2^2n =! O(2^n)

# %%
#Ejercicio 2
#Implement in Python the insertion sort procedure to sort into non-increasing instead of non-decreasing order

import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
